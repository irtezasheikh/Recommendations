# %%
import pandas as pd
import numpy as np 
from functools import reduce

# %%
import os

# %%
import matplotlib.pyplot as plt

# %%
viewers = ['John','Logan','Modesto','Malcom','Maurice']

# %%
movies = ['American Snippers','Edge Of Tommorrow','Groundhog day','Jurassic World','Lost In Translation','Lucy']

# %%
viewers.sort()

# %%
print(viewers)
# Out:
# ['John', 'Logan', 'Malcom', 'Maurice', 'Modesto']

# %%
movies.sort()

# %%
print(movies)
# Out:
# ['American Snippers', 'Edge Of Tommorrow', 'Groundhog day', 'Jurassic World', 'Lost In Translation', 'Lucy']

# %%
print(list((viewers,movies)))
# Out:
# [['John', 'Logan', 'Malcom', 'Maurice', 'Modesto'], ['American Snippers', 'Edge Of Tommorrow', 'Groundhog day', 'Jurassic World', 'Lost In Translation', 'Lucy']]

# %%
movie ='Lost In Translation'

# %%
sp = movie.split(" ",2)

# %%
print(movie)
# Out:
# Lost In Translation

# %%
c= list(filter(lambda x: x in viewers, movies))
print(c)
# Out:
# []

# %%
Ratings= [5,4,3,2,1]
a=list(map((lambda x: x ), Ratings))
print(a)
# Out:
# [5, 4, 3, 2, 1]

# %%
df = c

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x), x, np.cos(x));

# %%
df.index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
fav = reduce(lambda x,y:x, movies)
print(fav)
# Out:
# American Snippers
